# %% [markdown]
# <a href="https://colab.research.google.com/github/jonchung1205/DrugDiscovery/blob/main/CDD_ML_Part_1_Bioactivity_Data_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Computational Drug Discovery [Part 1] Download Bioactivity Data
#
#
# This project will focus on  building a machine learning model using the ChEMBL bioactivity data. Part 1 will focus on Data Collection and Pre-Processing from the ChEMBL Database.

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.

# %% [markdown]
# ## **Installing libraries**

# %%
! pip install chembl_webresource_client
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 770.6 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 3.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# jsonschema 4.19.2 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# referencing 0.32.0 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('ACC')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references              organism  \
# 0  [{'xref_id': 'P11497', 'xref_name': None, 'xre...     Rattus norvegicus
# 1  [{'xref_id': 'ACACB', 'xref_name': None, 'xref...          Homo sapiens
# 2                                                 []          Homo sapiens
# 3  [{'xref_id': 'A4ZYU9', 'xref_name': None, 'xre...      Escherichia coli
# 4                                                 []  Arabidopsis thaliana
# 5                                                 []          Mus musculus
# 6                                                 []     Rattus norvegicus
# 7  [{'xref_id': 'Q13085', 'xref_name': None, 'xre...          Homo sapiens
# 8  [{'xref_id': 'Q5SWU9', 'xref_name': None, 'xre...          Mus musculus
#
#                                       pref_name  score  species_group_flag  \
# 0                      Acetyl-CoA carboxylase 1   15.0               False
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human
#
# ---
#
# ACC* (first entry)**

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL2397'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 152                                               None             None
# 153                                               None             None
# 154                                               None           213374
# 155                                               None           213373
# 156  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id                                activity_properties  \
# ...

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('ACC_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-65-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 152                                               None             None
# 153                                               None             None
# 154                                               None           213374
# 155                                               None           213373
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 147

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 151                                               None             None
# 152                                               None             None
# 153                                               None             None
# 154                                               None           213374
# 156  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id                                activity_properties  \
# ...

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL326563              CCC/C(=N\OCC)C1=C(O)CC(CC(C)SCC)CC1=O
# 1         CHEMBL111617       C=CCO/N=C(\CCC)C1=C(O)C(C(=O)OC)C(C)(C)CC1=O
# 2         CHEMBL113137              CCC/C(=N\OCC)C1=C(O)CC(C2CCCSC2)CC1=O
# 3         CHEMBL111058       CCSC(C)CC1CC(=O)C(/C(CC)=N/OC/C=C/Cl)=C(O)C1
# 4          CHEMBL60556        CCO/N=C(\CC)C1=C(O)CC(c2c(C)cc(C)cc2C)CC1=O
# ..                 ...                                                ...
# 151      CHEMBL3629704  Cc1cc(C(=O)N2CC3(CCN(C(=O)OC(C)(C)C)CC3)C2)cc2...
# 152      CHEMBL3629703  Cc1cc(C(=O)N2CCC3(CCN(C(=O)OC(C)(C)C)C3)CC2)cc...
# 153      CHEMBL3629702  Cc1cc(C(=O)N2CCC3(CCN(C(=O)OC(C)(C)C)CC3)C2)cc...
# 154      CHEMBL3644846      CC(=O)N[C@@H](C)COc1ccc(Oc2ccc(OC(C)C)cc2)cc1
# 156      CHEMBL4567446  COc1cc(C(=O)N2CCC3(CC2)CC(=O)c2c(cnn2C(C)C)C3)...
#
#     standard_value
# 0          40000.0
# 1         100000.0
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('ACC_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('ACC_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id  ...         class
# 0          CHEMBL133897  ...        active
# 1          CHEMBL336398  ...        active
# 2          CHEMBL131588  ...      inactive
# 3          CHEMBL130628  ...        active
# 4          CHEMBL130478  ...        active
# ...                 ...  ...           ...
# 4690      CHEMBL4293155  ...  intermediate
# 4691      CHEMBL4282558  ...  intermediate
# 4692      CHEMBL4281727  ...  intermediate
# 4693      CHEMBL4292349  ...  intermediate
# 4694      CHEMBL4278260  ...  intermediate
#
# [4695 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('ACC_03_bioactivity_data_curated.csv', index=False)

# %%
! zip acetylcholinesterase.zip *.csv
# Out:
#   adding: acetylcholinesterase_01_bioactivity_data_raw.csv (deflated 90%)
#   adding: acetylcholinesterase_02_bioactivity_data_preprocessed.csv (deflated 81%)
#   adding: acetylcholinesterase_03_bioactivity_data_curated.csv (deflated 82%)

# %%
! ls -l
# Out:
# total 4668
# -rw-r--r-- 1 root root 3562870 Jun  1 15:03 acetylcholinesterase_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  342989 Jun  1 15:03 acetylcholinesterase_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  385924 Jun  1 15:03 acetylcholinesterase_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  475843 Jun  1 15:03 acetylcholinesterase.zip
# drwxr-xr-x 1 root root    4096 May 27 16:27 sample_data

# %% [markdown]
# ---
